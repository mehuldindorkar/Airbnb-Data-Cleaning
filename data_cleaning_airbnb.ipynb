# %%
import pandas as pd 
df = pd.read_csv("Airbnb_Open_Data.csv")
df.head()
# Out:
# C:\Users\MEHUL\AppData\Local\Temp\ipykernel_3048\1864760091.py:2: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("Airbnb_Open_Data.csv")
#         id                                              NAME      host id  \
# 0  1001254                Clean & quiet apt home by the park  80014485718
# 1  1002102                             Skylit Midtown Castle  52335172823
# 2  1002403               THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3  1002755                                               NaN  85098326012
# 4  1003689  Entire Apt: Spacious Studio/Loft by central park  92037596077
#
#   host_identity_verified host name neighbourhood group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
# 1               verified     Jenna           Manhattan       Midtown
# 2                    NaN     Elise           Manhattan        Harlem
# ...

# %%
df['house_rules'] = df['house_rules'].fillna("None do whatever you want")

# %%
newnm = [' Clean & quiet apt home by the park,Skylit Midtown Castle','THE VILLAGE OF HARLEM....NEW YORK !','Entire Apt: Spacious Studio/Loft by central park','Spare room in Williamsburg','Best Location near Columbia U','Comfy','bright room in Brooklyn','Big Studio-One Stop from Midtown','585 sf Luxury Studio']

# %%
import numpy as np 
df['NAME'] = df['NAME'].replace('nan','np.nan')
df['NAME'] = df['NAME'].apply(lambda x:np.random.choice(newnm) if pd.isnull(x) else x).str.title()
df['NAME'].isnull().sum()
# Out:
# np.int64(0)

# %%
df
# Out:
#              id                                              NAME  \
# 0       1001254                Clean & Quiet Apt Home By The Park
# 1       1002102                             Skylit Midtown Castle
# 2       1002403               The Village Of Harlem....New York !
# 3       1002755                  Big Studio-One Stop From Midtown
# 4       1003689  Entire Apt: Spacious Studio/Loft By Central Park
# ...         ...                                               ...
# 102594  6092437                        Spare Room In Williamsburg
# 102595  6092990                     Best Location Near Columbia U
# 102596  6093542                    Comfy, Bright Room In Brooklyn
# 102597  6094094                  Big Studio-One Stop From Midtown
# 102598  6094647                              585 Sf Luxury Studio
#
#             host id host_identity_verified    host name neighbourhood group  \
# 0       80014485718            unconfirmed     Madaline            Brooklyn
# ...

# %%
emptvalue = ['verified','uncomfirmed']

df['host_identity_verified'] = df['host_identity_verified'].apply(lambda x: np.random.choice(emptvalue) if pd.isnull(x) else x)
df['host_identity_verified'].isnull().sum()
df
# Out:
#              id                                              NAME  \
# 0       1001254                Clean & Quiet Apt Home By The Park
# 1       1002102                             Skylit Midtown Castle
# 2       1002403               The Village Of Harlem....New York !
# 3       1002755                  Big Studio-One Stop From Midtown
# 4       1003689  Entire Apt: Spacious Studio/Loft By Central Park
# ...         ...                                               ...
# 102594  6092437                        Spare Room In Williamsburg
# 102595  6092990                     Best Location Near Columbia U
# 102596  6093542                    Comfy, Bright Room In Brooklyn
# 102597  6094094                  Big Studio-One Stop From Midtown
# 102598  6094647                              585 Sf Luxury Studio
#
#             host id host_identity_verified    host name neighbourhood group  \
# 0       80014485718            unconfirmed     Madaline            Brooklyn
# ...

# %%
# df.head(20)
df.drop('country code',axis=1,inplace=True)

# %%
x1 = ['Madaline','Jenna','Elise','Garry','Lyndon','Michelle','Alberta','Emma','Evelyn','Carl','Miranda','Alan','Darcy','Leonardo','Daniel','Heather','Ryan','Alberta','Martin']
# print(x1)
df['host name'] = df['host name'].apply(lambda x: np.random.choice(x1) if pd.isnull(x) else x)

df.head(20)
# Out:
#          id                                              NAME      host id  \
# 0   1001254                Clean & Quiet Apt Home By The Park  80014485718
# 1   1002102                             Skylit Midtown Castle  52335172823
# 2   1002403               The Village Of Harlem....New York !  78829239556
# 3   1002755                  Big Studio-One Stop From Midtown  85098326012
# 4   1003689  Entire Apt: Spacious Studio/Loft By Central Park  92037596077
# 5   1004098         Large Cozy 1 Br Apartment In Midtown East  45498551794
# 6   1004650                                   Blissartsspace!  61300605564
# 7   1005202                                   Blissartsspace!  90821839709
# 8   1005754                   Large Furnished Room Near B'Way  79384379533
# 9   1006307                Cozy Clean Guest Room - Family Apt  75527839483
# 10  1006859                Cute & Cozy Lower East Side 1 Bdrm   1280143094
# ...

# %%
df.isnull().sum()
# Out:
# id                                     0
# NAME                                   0
# host id                                0
# host_identity_verified                 0
# host name                              0
# neighbourhood group                   29
# neighbourhood                         16
# lat                                    8
# long                                   8
# country                              532
# instant_bookable                     105
# cancellation_policy                   76
# room type                              0
# Construction year                    214
# price                                247
# service fee                          273
# minimum nights                       409
# number of reviews                    183
# last review                        15893
# reviews per month                  15879
# review rate number                   326
# calculated host listings count       319
# availability 365                     448
# ...

# %%
df.drop('neighbourhood group',axis=1,inplace=True)

# %%
neighbourhood_list = [
    'Kensington',
    'Midtown',
    'Harlem',
    'Clinton Hill',
    'East Harlem',
    'Murray Hill',
    'Bedford-Stuyvesant',
    "Hell's Kitchen",
    'Upper West Side',
    'Chinatown',
    'South Slope',
    'West Village',
    'Williamsburg',
    'Fort Greene',
    'Chelsea',
    'Crown Heights',
    'Park Slope',
    'Windsor Terrace',
    'Inwood',
    'East Village'
]

# %%
df['neighbourhood'] = df['neighbourhood'].apply(lambda x: np.random.choice(neighbourhood_list) if pd.isnull(x) else x)

# %%
df
# Out:
#              id                                              NAME  \
# 0       1001254                Clean & Quiet Apt Home By The Park
# 1       1002102                             Skylit Midtown Castle
# 2       1002403               The Village Of Harlem....New York !
# 3       1002755                  Big Studio-One Stop From Midtown
# 4       1003689  Entire Apt: Spacious Studio/Loft By Central Park
# ...         ...                                               ...
# 102594  6092437                        Spare Room In Williamsburg
# 102595  6092990                     Best Location Near Columbia U
# 102596  6093542                    Comfy, Bright Room In Brooklyn
# 102597  6094094                  Big Studio-One Stop From Midtown
# 102598  6094647                              585 Sf Luxury Studio
#
#             host id host_identity_verified    host name        neighbourhood  \
# 0       80014485718            unconfirmed     Madaline           Kensington
# ...

# %%
df.drop('host id',axis=1,inplace=True)

# %%
df.drop('minimum nights',axis=1,inplace=True)

# %%
df.drop('reviews per month',axis=1,inplace=True)

# %%
df.isnull().sum()
# Out:
# id                                     0
# NAME                                   0
# host_identity_verified                 0
# host name                              0
# neighbourhood                          0
# lat                                    8
# long                                   8
# country                              532
# instant_bookable                     105
# cancellation_policy                   76
# room type                              0
# Construction year                    214
# price                                247
# service fee                          273
# number of reviews                    183
# last review                        15893
# review rate number                   326
# calculated host listings count       319
# availability 365                     448
# house_rules                            0
# license                           102597
# dtype: int64

# %%
df['country'] = df['country'].fillna('United States')

# %%
s1 = ['TRUE','FALSE']
df['instant_bookable'] = df['instant_bookable'].apply(lambda x: np.random.choice(s1) if pd.isnull(x) else x)

# %%
# df['cancellation_policy']
st = ['strict','moderate','flexible']
df['instant_bookable'] = df['instant_bookable'].apply(lambda x: np.random.choice(s1) if pd.isnull(x) else x)

# %%
# df['Construction year'].max()
# df['Construction year'].min()

x1=[2022,2012,2004,2005,2006,2007,2010,2020,2021,2019,2015]
df['Construction year'] = df['Construction year'].apply(lambda x: np.random.choice(x1) if pd.isnull(x) else x)

# %%
df['price'] = pd.to_numeric(df['price'].replace('[\$,]','',regex=True))
df['price']
df['price'] = df['price'].fillna(df['price'].mean()).astype(int)
df['price'].isnull().sum()
df['price'] = '$' + df['price'].astype(str)
df['price']
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\$'
# <>:1: SyntaxWarning: invalid escape sequence '\$'
# C:\Users\MEHUL\AppData\Local\Temp\ipykernel_3048\3231069412.py:1: SyntaxWarning: invalid escape sequence '\$'
#   df['price'] = pd.to_numeric(df['price'].replace('[\$,]','',regex=True))
# 0          $966
# 1          $142
# 2          $620
# 3          $368
# 4          $204
#           ...
# 102594     $844
# 102595     $837
# 102596     $988
# 102597     $546
# 102598    $1032
# Name: price, Length: 102599, dtype: object

# %%
df['service fee'].head(20)
# Out:
# 0     $193
# 1      $28
# 2     $124
# 3      $74
# 4      $41
# 5     $115
# 6      $14
# 7     $212
# 8     $204
# 9      $58
# 10     $64
# 11    $121
# 12    $143
# 13    $116
# 14     $30
# 15      NaN
# 16      NaN
# 17      NaN
# 18      NaN
# 19      NaN
# Name: service fee, dtype: object

# %%
df['service fee'] = pd.to_numeric(df['service fee'].replace('[\$,]','',regex=True))
df['service fee'] = df['service fee'].fillna(df['service fee'].mean()).astype(int)
# df['service fee'].isnull().sum()
df['service fee'] = '$' + df['service fee'].astype(str)
df['service fee'].head(20)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\$'
# <>:1: SyntaxWarning: invalid escape sequence '\$'
# C:\Users\MEHUL\AppData\Local\Temp\ipykernel_3048\2229584007.py:1: SyntaxWarning: invalid escape sequence '\$'
#   df['service fee'] = pd.to_numeric(df['service fee'].replace('[\$,]','',regex=True))
# 0     $193
# 1      $28
# 2     $124
# 3      $74
# 4      $41
# 5     $115
# 6      $14
# 7     $212
# 8     $204
# 9      $58
# 10     $64
# 11    $121
# 12    $143
# 13    $116
# 14     $30
# 15    $125
# 16    $125
# 17    $125
# 18    $125
# 19    $125
# Name: service fee, dtype: object

# %%
df['number of reviews'] = df['number of reviews'].fillna(df['number of reviews'].mean()).astype(int)

# %%
df['number of reviews']
# Out:
# 0           9
# 1          45
# 2           0
# 3         270
# 4           9
#          ...
# 102594      0
# 102595      1
# 102596      0
# 102597      5
# 102598      0
# Name: number of reviews, Length: 102599, dtype: int64

# %%
df.drop('last review',axis=1,inplace=True)

# %%
sd = [1,2,3,4,5]
df['review rate number'] = df['review rate number'].apply(lambda x: np.random.choice(sd) if pd.isnull(x) else x).astype(int)

# %%
df['review rate number']
# Out:
# 0         4
# 1         4
# 2         5
# 3         4
# 4         3
#          ..
# 102594    3
# 102595    2
# 102596    5
# 102597    3
# 102598    3
# Name: review rate number, Length: 102599, dtype: int64

# %%
df.isnull().sum()
# Out:
# id                                     0
# NAME                                   0
# host_identity_verified                 0
# host name                              0
# neighbourhood                          0
# lat                                    8
# long                                   8
# country                                0
# instant_bookable                       0
# cancellation_policy                   76
# room type                              0
# Construction year                      0
# price                                  0
# service fee                            0
# number of reviews                      0
# review rate number                     0
# calculated host listings count       319
# availability 365                     448
# house_rules                            0
# license                           102597
# dtype: int64

# %%
df['house_rules'].isnull().sum()
# Out:
# np.int64(0)

# %%
df.drop('license',axis=1,inplace=True)

# %%
s1=['strict''moderate','flexible']

df['cancellation_policy'] = df['cancellation_policy'].apply(lambda x: np.random.choice(s1) if pd.isnull(x) else x)

# %%
df.isnull().sum()
# Out:
# id                                  0
# NAME                                0
# host_identity_verified              0
# host name                           0
# neighbourhood                       0
# lat                                 8
# long                                8
# country                             0
# instant_bookable                    0
# cancellation_policy                 0
# room type                           0
# Construction year                   0
# price                               0
# service fee                         0
# number of reviews                   0
# review rate number                  0
# calculated host listings count    319
# availability 365                  448
# house_rules                         0
# dtype: int64

# %%
df.drop('id',axis=1,inplace=True)

# %%
df.drop('host_identity_verified',axis=1,inplace=True)

# %%
df['calculated host listings count'].min()
df['calculated host listings count'].max()
# Out:
# np.float64(332.0)

# %%
x1 = [12, 295, 88, 174, 39, 301, 242, 151, 213, 119, 275, 90, 201, 265, 60, 143, 248, 37, 106, 223,
 178, 52, 5, 128, 194, 292, 310, 269, 203, 16, 84, 136, 70, 145, 160, 19, 286, 102, 309, 32,
 290, 211, 221, 97, 230, 185, 304, 206, 123, 56]

df['calculated host listings count'] = df['calculated host listings count'].apply(lambda x: np.random.choice(x1) if pd.isnull(x) else x)

# %%
df['availability 365'].max()
# Out:
# np.float64(3677.0)

# %%
# df.drop('NAME',axis=1,inplace=True)
df.drop('host name',axis=1,inplace=True)

# %%
df.isnull().sum()
# Out:
# host name                           0
# neighbourhood                       0
# lat                                 8
# long                                8
# country                             0
# instant_bookable                    0
# cancellation_policy                 0
# room type                           0
# Construction year                   0
# price                               0
# service fee                         0
# number of reviews                   0
# review rate number                  0
# calculated host listings count      0
# availability 365                  448
# house_rules                         0
# dtype: int64

# %%
df.to_csv('Cleaned_dataset_airbnb.csv',index=False)
